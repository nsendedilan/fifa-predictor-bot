# %%
requirements = """
telethon
pandas
numpy
scikit-learn
xgboost
joblib
"""

with open("requirements.txt", "w") as f:
    f.write(requirements)

print("✅ requirements.txt created")
# Out:
# ✅ requirements.txt created

# %%
procfile = "worker: python test_live.py"

with open("Procfile", "w") as f:
    f.write(procfile)

print("✅ Procfile created")
# Out:
# ✅ Procfile created

# %%
gitignore = """
__pycache__/
*.session
*.session-journal
.ipynb_checkpoints/
history.json
"""

with open(".gitignore", "w") as f:
    f.write(gitignore)

print("✅ .gitignore created")
# Out:
# ✅ .gitignore created
